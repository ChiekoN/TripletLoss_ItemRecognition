# %% [markdown]
# # Script to divide image data into train and test directory
#
#  - `./train/food` : Training data, image of food
#  - `./train/no_food` : Training data, image of no-food
#  - `./valid/food` : Validation data, image of food
#  - `./valid/no_food` : Validation data, image of no-food
#  - `./test/food` : Test data, image of food
#  - `./test/no_food` : Test data, image of no-food

# %%
import os
import numpy as np
from os import listdir
import random
import shutil

import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %matplotlib inline

# %%
base_dir = os.getcwd()
print(base_dir)
# Out:
# /home/chieko/Projects/ImageRecognition

# %%
def rgba_to_jpg(rgba_img):
    # https://stackoverflow.com/questions/9166400/convert-rgba-png-to-rgb-with-pil
    
    # print(" <In rgba_to_jpg> : {}".format(filename))
    background = Image.new('RGBA', rgba_img.size, (255,255,255))
    
    alpha_composite = Image.alpha_composite(background, rgba_img)
    
    return alpha_composite.convert('RGB')

    

def copy_files(data_dir, copy_dir):
    #category = os.path.basename(dirname)
    #path = os.path.dirname(dirname)
    
    orig_dirs = [d for d in listdir(data_dir) if os.path.isdir(os.path.join(data_dir, d))]
    print("Number of dirs : {}".format(len(orig_dirs)))
    print("from: {}, to: {}".format(data_dir, copy_dir))
    #print(orig_dirs)
    
    # Shuffle the sequence
    random.shuffle(orig_dirs) 
    
    # Train 80%, valid 10%, test 10%
    train_num = len(orig_dirs)*0.8
    valid_num = len(orig_dirs)*0.1
    
    for i, d in enumerate(orig_dirs):
        from_d = os.path.join(data_dir, d)
        
        if i < train_num:
            to_dir = os.path.join(os.path.join(copy_dir, 'train'), d)

        elif i >= train_num and i < train_num + valid_num:
            to_dir = os.path.join(os.path.join(copy_dir, 'valid'), d)

        else:
            to_dir = os.path.join(os.path.join(copy_dir, 'test'), d)

        os.makedirs(to_dir)
    
        for ii, f in enumerate([f for f in listdir(from_d) if os.path.isfile(os.path.join(from_d, f))]):
            # resize image if it's too big (larger than 640px at the longest edge)
            MAXLEN = 640

            img = os.path.join(from_d, f)
            im = Image.open(img)
            w, h = im.size
            maxedge = max((w, h))
            if maxedge > MAXLEN:
                r = MAXLEN / maxedge
                new_w = int(w * r)
                new_h = int(h * r)
                im = im.resize((new_w, new_h)) 
            
            # Check mode and convert into JPG, also rename filename to ".jpg"
            if im.mode == 'RGBA':          
                im = rgba_to_jpg(im)
                new_fname = f.split('.')[0] + ".jpg"
                print(" <RGBA> : {} -> {}".format(f, new_fname))

            elif im.mode == 'P':
                im = im.convert("RGB")
                new_fname = f.split('.')[0] + ".jpg"
                print(" <P> : {} -> {}".format(f, new_fname))

            else:
                ext = f.split('.')[1]
                if im.mode == 'RGB' and \
                   ext != "jpg" and ext != "jpeg" and ext != "JPG" and ext != "JPEG":               
                    new_fname = f.split('.')[0] + ".jpg"
                    print(" <rename> : {} -> {}".format(f, new_fname))
                else:
                    new_fname = f

            im.save(os.path.join(to_dir, new_fname), "JPEG")
            #print("{} : {}".format(to_dir, new_fname))
        
        if i%500 == 0:
            print(". ", end = '')
        
        #if i>5:
            #break

    return

# %%
data_dir = os.path.join(base_dir, 'data')
copy_dir = os.path.join(base_dir, 'image_data')
train_dir = os.path.join(copy_dir, 'train')
valid_dir = os.path.join(copy_dir, 'valid')
test_dir = os.path.join(copy_dir, 'test')

if os.path.exists(train_dir):
    shutil.rmtree(train_dir)
os.makedirs(train_dir)

if os.path.exists(valid_dir):
    shutil.rmtree(valid_dir)
os.makedirs(valid_dir)

if os.path.exists(test_dir):
    shutil.rmtree(test_dir)
os.makedirs(test_dir)

print("Making data started!")
copy_files(data_dir, copy_dir)
print("\nFinished!")
# Out:
# Making data started!
# Number of dirs : 898
# from: /home/chieko/Projects/ImageRecognition/data, to: /home/chieko/Projects/ImageRecognition/image_data
# .  <RGBA> : ice_44_000011.jpg -> ice_44_000011.jpg
#  <P> : aubeer2_89_000049.jpg -> aubeer2_89_000049.jpg
#  <RGBA> : ausnack_97_000029.jpg -> ausnack_97_000029.jpg
#  <RGBA> : ausnack_97_000033.jpg -> ausnack_97_000033.jpg
#  <RGBA> : austeafood_000026_000046.jpg -> austeafood_000026_000046.jpg
#  <RGBA> : aubeer_20_000029.jpg -> aubeer_20_000029.jpg
#  <RGBA> : aubeer_20_000015.jpg -> aubeer_20_000015.jpg
#  <RGBA> : aubeer_20_000047.jpeg -> aubeer_20_000047.jpg
#  <RGBA> : aubeer_20_000024.jpg -> aubeer_20_000024.jpg
#  <RGBA> : drink22_000023.jpg -> drink22_000023.jpg
#  <RGBA> : ice_71_000006.jpg -> ice_71_000006.jpg
#  <RGBA> : austeafood_000083_000016.jpg -> austeafood_000083_000016.jpg
#  <RGBA> : snack6_000002.jpg -> snack6_000002.jpg
#  <RGBA> : snack6_000018.jpg -> snack6_000018.jpg
#  <RGBA> : ice_26_000035.jpg -> ice_26_000035.jpg
#  <RGBA> : aubeer_100_000004.jpg -> aubeer_100_000004.jpg
#  <RGBA> : aubeer_36_000016.jpg -> aubeer_36_000016.jpg
#  <RGBA> : austeafood_000042_000040.jpg -> austeafood_000042_000040.jpg
#  <RGBA> : snack135_000003.jpg -> snack135_000003.jpg
#  <P> : cereal_88_000030.jpg -> cereal_88_000030.jpg
#  <RGBA> : aubeer2_1_000042.jpg -> aubeer2_1_000042.jpg
#  <RGBA> : aubeer2_1_000026.jpg -> aubeer2_1_000026.jpg
#  <RGBA> : aubeer2_7_000004.jpg -> aubeer2_7_000004.jpg
#  <RGBA> : aubeer2_7_000003.jpg -> aubeer2_7_000003.jpg
#  <RGBA> : aubeer2_50_000003.jpg -> aubeer2_50_000003.jpg
#  <RGBA> : ice_39_000005.jpg -> ice_39_000005.jpg
#  <RGBA> : ice_103_000032.jpg -> ice_103_000032.jpg
#  <RGBA> : ice_103_000004.jpg -> ice_103_000004.jpg
#  <rename> : aubeer2_86_000042.bmp -> aubeer2_86_000042.jpg
#  <RGBA> : aubeer2_86_000006.jpeg -> aubeer2_86_000006.jpg
#  <RGBA> : audrink_113_000013.jpg -> audrink_113_000013.jpg
#  <RGBA> : aubeer_48_000015.jpg -> aubeer_48_000015.jpg
#  <RGBA> : aubeer_48_000003.jpeg -> aubeer_48_000003.jpg
#  <RGBA> : aubeer2_42_000020.jpg -> aubeer2_42_000020.jpg
#  <RGBA> : austeafood_000063_000013.jpg -> austeafood_000063_000013.jpg
#  <RGBA> : aubeer2_69_000024.jpg -> aubeer2_69_000024.jpg
#  <RGBA> : cereal_15_000010.jpeg -> cereal_15_000010.jpg
#  <RGBA> : austeafood_000066_000041.jpg -> austeafood_000066_000041.jpg
#  <RGBA> : austeafood_000066_000048.jpg -> austeafood_000066_000048.jpg
#  <RGBA> : austeafood_000066_000035.jpg -> austeafood_000066_000035.jpg
#  <RGBA> : austeafood_000066_000034.jpg -> austeafood_000066_000034.jpg
#  <RGBA> : aubeer_79_000006.jpeg -> aubeer_79_000006.jpg
#  <RGBA> : aubeer_79_000026.jpg -> aubeer_79_000026.jpg
#  <RGBA> : ausnack_144_000026.jpg -> ausnack_144_000026.jpg
#  <RGBA> : audrink_162_000002.jpg -> audrink_162_000002.jpg
#  <RGBA> : aubeer_1_000004.jpg -> aubeer_1_000004.jpg
#  <RGBA> : ice_46_000003.jpg -> ice_46_000003.jpg
#  <RGBA> : audrink_70_000032.jpg -> audrink_70_000032.jpg
#  <RGBA> : audrink_70_000016.jpg -> audrink_70_000016.jpg
#  <RGBA> : aubeer_96_000011.jpg -> aubeer_96_000011.jpg
#  <RGBA> : austeafood_000047_000003.jpg -> austeafood_000047_000003.jpg
#  <RGBA> : austeafood_000078_000022.jpg -> austeafood_000078_000022.jpg
#  <RGBA> : austeafood_000078_000004.jpg -> austeafood_000078_000004.jpg
#  <RGBA> : audrink_92_000037.jpg -> audrink_92_000037.jpg
#  <RGBA> : aubeer2_49_000004.jpg -> aubeer2_49_000004.jpg
#  <RGBA> : aubeer_34_000024.jpg -> aubeer_34_000024.jpg
#  <RGBA> : ice_107_000013.jpg -> ice_107_000013.jpg
#  <RGBA> : aubeer_51_000007.jpeg -> aubeer_51_000007.jpg
#  <RGBA> : ausnack_141_000007.jpg -> ausnack_141_000007.jpg
#  <RGBA> : ice_82_000008.jpg -> ice_82_000008.jpg
#  <RGBA> : aubeer_103_000016.jpg -> aubeer_103_000016.jpg
#  <RGBA> : aubeer2_14_000013.jpg -> aubeer2_14_000013.jpg
#  <RGBA> : aubeer2_14_000006.jpg -> aubeer2_14_000006.jpg
#  <RGBA> : ice_156_000003.jpg -> ice_156_000003.jpg
#  <RGBA> : aubeer_2_000002.jpg -> aubeer_2_000002.jpg
#  <RGBA> : austeafood_000029_000023.jpg -> austeafood_000029_000023.jpg
#  <RGBA> : austeafood_000029_000033.jpg -> austeafood_000029_000033.jpg
#  <RGBA> : austeafood_000095_000041.jpg -> austeafood_000095_000041.jpg
#  <RGBA> : aubeer2_65_000050.jpg -> aubeer2_65_000050.jpg
#  <RGBA> : aubeer2_65_000044.jpg -> aubeer2_65_000044.jpg
#  <RGBA> : aubeer2_65_000009.jpg -> aubeer2_65_000009.jpg
#  <RGBA> : audrink_172_000004.jpg -> audrink_172_000004.jpg
#  <RGBA> : ausnack_147_000020.jpg -> ausnack_147_000020.jpg
#  <RGBA> : drink93_000028.jpg -> drink93_000028.jpg
#  <P> : aubeer_27_000017.jpeg -> aubeer_27_000017.jpg
#  <RGBA> : audrink_152_000025.jpg -> audrink_152_000025.jpg
#  <RGBA> : audrink_152_000012.jpg -> audrink_152_000012.jpg
#  <RGBA> : aubeer_43_000041.jpg -> aubeer_43_000041.jpg
#  <RGBA> : aubeer_43_000007.jpg -> aubeer_43_000007.jpg
#  <RGBA> : aubeer_43_000002.jpg -> aubeer_43_000002.jpg
#  <RGBA> : austeafood_000072_000014.jpg -> austeafood_000072_000014.jpg
#  <RGBA> : aubeer2_34_000008.jpg -> aubeer2_34_000008.jpg
#  <RGBA> : aubeer2_34_000042.jpg -> aubeer2_34_000042.jpg
#  <RGBA> : ausnack_59_000012.jpg -> ausnack_59_000012.jpg
#  <RGBA> : austeafood_000017_000001.jpg -> austeafood_000017_000001.jpg
#  <RGBA> : austeafood_000080_000039.jpg -> austeafood_000080_000039.jpg
#  <RGBA> : aubeer2_6_000027.jpg -> aubeer2_6_000027.jpg
#  <RGBA> : aubeer2_6_000021.jpg -> aubeer2_6_000021.jpg
#  <RGBA> : aubeer_97_000023.jpg -> aubeer_97_000023.jpg
#  <RGBA> : aubeer_97_000015.jpg -> aubeer_97_000015.jpg
#  <RGBA> : aubeer_52_000008.jpg -> aubeer_52_000008.jpg
#  <RGBA> : ice_65_000037.jpg -> ice_65_000037.jpg
#  <RGBA> : aubeer_4_000006.jpg -> aubeer_4_000006.jpg
#  <RGBA> : aubeer_4_000009.jpeg -> aubeer_4_000009.jpg
#  <RGBA> : aubeer_12_000018.jpg -> aubeer_12_000018.jpg
#  <RGBA> : aubeer_12_000004.jpeg -> aubeer_12_000004.jpg
#  <P> : aubeer_10_000023.jpg -> aubeer_10_000023.jpg
#  <RGBA> : cereal_76_000003.jpg -> cereal_76_000003.jpg
#  <RGBA> : ice_80_000006.jpg -> ice_80_000006.jpg
#  <RGBA> : aubeer_14_000006.jpeg -> aubeer_14_000006.jpg
#  <RGBA> : aubeer_14_000002.jpg -> aubeer_14_000002.jpg
#  <RGBA> : austeafood_000097_000036.jpg -> austeafood_000097_000036.jpg
#  <RGBA> : austeafood_000097_000032.jpg -> austeafood_000097_000032.jpg
#  <RGBA> : austeafood_000003_000009.jpeg -> austeafood_000003_000009.jpg
#  <RGBA> : aubeer_8_000038.jpg -> aubeer_8_000038.jpg
#  <RGBA> : austeafood_000006_000026.jpg -> austeafood_000006_000026.jpg
#  <RGBA> : austeafood_000006_000036.jpg -> austeafood_000006_000036.jpg
#  <RGBA> : aubeer2_4_000018.jpg -> aubeer2_4_000018.jpg
#  <RGBA> : aubeer_54_000024.jpg -> aubeer_54_000024.jpg
#  <RGBA> : aubeer_54_000021.jpg -> aubeer_54_000021.jpg
#  <RGBA> : aubeer_95_000036.jpg -> aubeer_95_000036.jpg
#  <RGBA> : aubeer_95_000003.jpeg -> aubeer_95_000003.jpg
#  <RGBA> : aubeer2_77_000019.jpg -> aubeer2_77_000019.jpg
#  <RGBA> : aubeer2_77_000008.jpg -> aubeer2_77_000008.jpg
#  <RGBA> : austeafood_000005_000011.jpg -> austeafood_000005_000011.jpg
#  <RGBA> : ice_24_000005.jpg -> ice_24_000005.jpg
#  <RGBA> : aubeer2_81_000009.jpg -> aubeer2_81_000009.jpg
#  <RGBA> : ice_49_000002.jpg -> ice_49_000002.jpg
#  <RGBA> : aubeer_53_000033.jpg -> aubeer_53_000033.jpg
#  <RGBA> : aubeer2_44_000011.jpg -> aubeer2_44_000011.jpg
#  <RGBA> : aubeer2_19_000002.jpg -> aubeer2_19_000002.jpg
#  <RGBA> : aubeer2_19_000003.jpg -> aubeer2_19_000003.jpg
#  <RGBA> : aubeer2_19_000001.jpg -> aubeer2_19_000001.jpg
# .  <RGBA> : aubeer2_18_000022.jpg -> aubeer2_18_000022.jpg
#  <RGBA> : aubeer2_18_000025.jpg -> aubeer2_18_000025.jpg
#  <RGBA> : aubeer2_18_000027.jpg -> aubeer2_18_000027.jpg
#  <RGBA> : aubeer2_11_000006.jpeg -> aubeer2_11_000006.jpg
#  <RGBA> : aubeer2_11_000020.jpg -> aubeer2_11_000020.jpg
#  <RGBA> : aubeer_26_000002.jpg -> aubeer_26_000002.jpg
#  <RGBA> : ausnack_91_000005.jpg -> ausnack_91_000005.jpg
#  <RGBA> : aubeer_15_000044.jpg -> aubeer_15_000044.jpg
#  <RGBA> : aubeer2_33_000001.jpg -> aubeer2_33_000001.jpg
#  <RGBA> : aubeer2_33_000044.jpg -> aubeer2_33_000044.jpg
#  <RGBA> : aubeer2_52_000038.jpg -> aubeer2_52_000038.jpg
#  <RGBA> : aubeer2_52_000041.jpg -> aubeer2_52_000041.jpg
#  <RGBA> : aubeer2_17_000038.jpg -> aubeer2_17_000038.jpg
#  <RGBA> : aubeer_78_000009.jpg -> aubeer_78_000009.jpg
#  <RGBA> : aubeer2_53_000033.jpg -> aubeer2_53_000033.jpg
#  <RGBA> : aubeer2_2_000017.jpeg -> aubeer2_2_000017.jpg
#  <RGBA> : aubeer2_2_000049.jpg -> aubeer2_2_000049.jpg
#  <RGBA> : ice_16_000002.jpg -> ice_16_000002.jpg
#  <RGBA> : ice_16_000001.jpg -> ice_16_000001.jpg
#  <RGBA> : austeafood_000041_000020.jpg -> austeafood_000041_000020.jpg
#  <RGBA> : austeafood_000002_000029.jpg -> austeafood_000002_000029.jpg
#  <RGBA> : aubeer_61_000036.jpg -> aubeer_61_000036.jpg
#  <RGBA> : snack125_000003.jpg -> snack125_000003.jpg
#  <RGBA> : audrink_98_000041.jpg -> audrink_98_000041.jpg
#  <P> : audrink_98_000027.jpg -> audrink_98_000027.jpg
#  <RGBA> : audrink_98_000016.jpg -> audrink_98_000016.jpg
#  <RGBA> : ice_154_000007.jpg -> ice_154_000007.jpg
#  <RGBA> : aubeer2_67_000023.jpg -> aubeer2_67_000023.jpg
#  <RGBA> : audrink_123_000034.jpg -> audrink_123_000034.jpg
#  <RGBA> : aubeer2_15_000007.jpg -> aubeer2_15_000007.jpg
#  <RGBA> : aubeer2_15_000006.jpg -> aubeer2_15_000006.jpg
#  <RGBA> : aubeer2_15_000027.jpg -> aubeer2_15_000027.jpg
#  <RGBA> : aubeer2_15_000008.jpg -> aubeer2_15_000008.jpg
#  <RGBA> : aubeer2_15_000017.jpg -> aubeer2_15_000017.jpg
#  <RGBA> : aubeer2_15_000023.jpg -> aubeer2_15_000023.jpg
#  <RGBA> : ice_17_000010.jpg -> ice_17_000010.jpg
#  <RGBA> : ausnack_76_000007.jpg -> ausnack_76_000007.jpg
#  <RGBA> : austeafood_000053_000003.jpg -> austeafood_000053_000003.jpg
#  <RGBA> : ice_126_000002.jpg -> ice_126_000002.jpg
#  <RGBA> : austeafood_000096_000017.jpg -> austeafood_000096_000017.jpg
#  <RGBA> : austeafood_000096_000022.jpg -> austeafood_000096_000022.jpg
#  <RGBA> : aubeer_25_000023.jpg -> aubeer_25_000023.jpg
#  <RGBA> : aubeer_25_000004.jpg -> aubeer_25_000004.jpg
#  <RGBA> : aubeer2_12_000014.jpeg -> aubeer2_12_000014.jpg
#  <RGBA> : audrink_160_000006.jpg -> audrink_160_000006.jpg
#  <RGBA> : audrink_160_000007.jpg -> audrink_160_000007.jpg
#  <RGBA> : ice_73_000007.jpg -> ice_73_000007.jpg
#  <RGBA> : audrink_148_000007.jpg -> audrink_148_000007.jpg
#  <RGBA> : cereal_52_000025.jpg -> cereal_52_000025.jpg
#  <RGBA> : aubeer2_0_000026.jpg -> aubeer2_0_000026.jpg
#  <RGBA> : aubeer_23_000027.jpg -> aubeer_23_000027.jpg
#  <RGBA> : ice_130_000004.jpg -> ice_130_000004.jpg
#  <RGBA> : ice_100_000002.jpg -> ice_100_000002.jpg
#  <RGBA> : ice_100_000030.jpg -> ice_100_000030.jpg
#  <RGBA> : aubeer_89_000028.jpg -> aubeer_89_000028.jpg
#  <P> : audrink_27_000045.jpg -> audrink_27_000045.jpg
#  <RGBA> : aubeer_5_000036.jpg -> aubeer_5_000036.jpg
#  <RGBA> : aubeer_5_000013.jpg -> aubeer_5_000013.jpg
#  <RGBA> : austeafood_000056_000006.jpg -> austeafood_000056_000006.jpg
#  <RGBA> : aubeer_19_000002.jpg -> aubeer_19_000002.jpg
#  <RGBA> : aubeer_19_000013.jpg -> aubeer_19_000013.jpg
#  <RGBA> : aubeer_85_000035.jpg -> aubeer_85_000035.jpg
#  <RGBA> : austeafood_000022_000033.jpg -> austeafood_000022_000033.jpg
#  <RGBA> : audrink_30_000013.jpg -> audrink_30_000013.jpg
#  <RGBA> : ice_3_000001.jpg -> ice_3_000001.jpg
#  <RGBA> : aubeer_29_000031.jpg -> aubeer_29_000031.jpg
#  <RGBA> : aubeer2_37_000031.jpeg -> aubeer2_37_000031.jpg
#  <RGBA> : aubeer2_56_000010.jpg -> aubeer2_56_000010.jpg
#  <RGBA> : aubeer_88_000037.jpg -> aubeer_88_000037.jpg
#  <RGBA> : aubeer_44_000005.jpg -> aubeer_44_000005.jpg
#  <RGBA> : ausnack_1_000012.jpg -> ausnack_1_000012.jpg
#  <RGBA> : ausnack_1_000031.jpg -> ausnack_1_000031.jpg
#  <RGBA> : austeafood_000077_000006.jpg -> austeafood_000077_000006.jpg
#  <RGBA> : austeafood_000014_000002.jpg -> austeafood_000014_000002.jpg
#  <RGBA> : austeafood_000060_000022.jpg -> austeafood_000060_000022.jpg
#  <RGBA> : aubeer2_78_000012.jpg -> aubeer2_78_000012.jpg
#  <RGBA> : aubeer2_13_000017.jpg -> aubeer2_13_000017.jpg
#  <RGBA> : aubeer2_92_000014.jpg -> aubeer2_92_000014.jpg
#  <RGBA> : aubeer2_92_000037.jpg -> aubeer2_92_000037.jpg
#  <RGBA> : austeafood_000094_000028.jpg -> austeafood_000094_000028.jpg
#  <RGBA> : austeafood_000094_000008.jpg -> austeafood_000094_000008.jpg
#  <RGBA> : audrink_100_000001.jpg -> audrink_100_000001.jpg
#  <RGBA> : cereal_21_000018.jpg -> cereal_21_000018.jpg
#  <RGBA> : austeafood_000048_000002.jpg -> austeafood_000048_000002.jpg
#  <RGBA> : aubeer_11_000034.jpg -> aubeer_11_000034.jpg
#  <RGBA> : aubeer_11_000008.jpg -> aubeer_11_000008.jpg
#  <RGBA> : aubeer_45_000021.jpg -> aubeer_45_000021.jpg
#  <RGBA> : cereal_10_000009.jpg -> cereal_10_000009.jpg
#  <RGBA> : aubeer_0_000026.jpg -> aubeer_0_000026.jpg
#  <RGBA> : aubeer_0_000040.jpg -> aubeer_0_000040.jpg
#  <RGBA> : aubeer_32_000008.jpg -> aubeer_32_000008.jpg
#  <RGBA> : aubeer_32_000012.jpg -> aubeer_32_000012.jpg
#  <RGBA> : ice_84_000020.jpg -> ice_84_000020.jpg
#  <RGBA> : austeafood_000051_000005.jpg -> austeafood_000051_000005.jpg
#  <RGBA> : aubeer_46_000018.jpg -> aubeer_46_000018.jpg
#  <RGBA> : aubeer_46_000005.jpg -> aubeer_46_000005.jpg
#  <RGBA> : cereal_51_000005.jpg -> cereal_51_000005.jpg
#  <RGBA> : ice_161_000004.jpg -> ice_161_000004.jpg
#  <RGBA> : ice_161_000007.jpg -> ice_161_000007.jpg
#  <RGBA> : ice_161_000006.jpg -> ice_161_000006.jpg
#  <RGBA> : austeafood_000089_000007.jpg -> austeafood_000089_000007.jpg
#  <RGBA> : aubeer2_60_000045.jpg -> aubeer2_60_000045.jpg
#  <RGBA> : austeafood_000052_000032.jpg -> austeafood_000052_000032.jpg
#  <RGBA> : austeafood_000050_000003.jpg -> austeafood_000050_000003.jpg
#  <RGBA> : austeafood_000016_000025.jpg -> austeafood_000016_000025.jpg
#
# Finished!

# %%
print("Number of categories in train data = {}".format(len(listdir(train_dir))))
print("Number of categories in valid data = {}".format(len(listdir(valid_dir))))
print("Number of categories in test data = {}".format(len(listdir(test_dir))))
# Out:
# Number of categories in train data = 719
# Number of categories in valid data = 90
# Number of categories in test data = 89

# %%
#print("---- Training data --------")
train_images = 0
for t in listdir(train_dir):
    #print("{} : {}".format(t, len(listdir(os.path.join(train_dir, t)))))
    train_images += len(listdir(os.path.join(train_dir, t)))

valid_images = 0
#print("---- Validation data --------")
for t in listdir(valid_dir):
    #print("{} : {}".format(t, len(listdir(os.path.join(valid_dir, t)))))
    valid_images += len(listdir(os.path.join(valid_dir, t)))
    
test_images = 0
#print("---- Test data --------")
for t in listdir(test_dir):
    #print("{} : {}".format(t, len(listdir(os.path.join(test_dir, t)))))
    test_images += len(listdir(os.path.join(test_dir, t)))
    
print("Total number of train images = {}".format(train_images))
print("Total number of valid images = {}".format(valid_images))
print("Total number of test images = {}".format(test_images))
# Out:
# Total number of train images = 12122
# Total number of valid images = 1589
# Total number of test images = 1447
